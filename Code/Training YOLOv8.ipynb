# %%
# !nvidia-smi
# Out:
# Sun Mar  3 13:50:43 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !cp -r /content/drive/MyDrive/skenny/data/YOLODataset /content/

# %%
# !mv /content/YOLODataset /content/datasets

# %%
# !unzip /content/drive/MyDrive/skenny/datasets.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/skenny/datasets.zip
#    creating: /content/datasets/
#   inflating: /content/datasets/dataset.yaml
#    creating: /content/datasets/test/
#    creating: /content/datasets/test/images/
#   inflating: /content/datasets/test/images/102.png
#   inflating: /content/datasets/test/images/105.png
#   inflating: /content/datasets/test/images/107.png
#   inflating: /content/datasets/test/images/109.png
#   inflating: /content/datasets/test/images/114.png
#   inflating: /content/datasets/test/images/120.png
#   inflating: /content/datasets/test/images/121.png
#   inflating: /content/datasets/test/images/125.png
#   inflating: /content/datasets/test/images/147.png
#   inflating: /content/datasets/test/images/153.png
#   inflating: /content/datasets/test/images/155.png
#   inflating: /content/datasets/test/images/156.png
#   inflating: /content/datasets/test/images/178.png
#   inflating: /content/datasets/test/images/18.png
# ...

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 35.6/78.2 GB disk)

# %% [markdown]
# https://docs.ultralytics.com/usage/cli/

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="datasets/dataset.yaml" epochs=20 plots=True

# best hyperparameter
# optimizer="Adam" imgsz=800 lr0=0.0016 batch=8 momentum=0.9 weight_decay=0.00128 plots=True
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 132MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r /content/drive/MyDrive/skenny/run.zip /content/runs

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.3 source=https://www.youtube.com/watch?v=MePT9d4xZ5s save=True

# %%
# !cp -r /content/runs /content/drive/MyDrive/skenny/

# %%
# !unzip /content/drive/MyDrive/skenny/run.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/skenny/run.zip
#    creating: /content/content/runs/
#    creating: /content/content/runs/detect/
#    creating: /content/content/runs/detect/train/
#   inflating: /content/content/runs/detect/train/train_batch0.jpg
#   inflating: /content/content/runs/detect/train/train_batch1.jpg
#   inflating: /content/content/runs/detect/train/val_batch0_pred.jpg
#   inflating: /content/content/runs/detect/train/train_batch411.jpg
#   inflating: /content/content/runs/detect/train/results.png
#   inflating: /content/content/runs/detect/train/args.yaml
#   inflating: /content/content/runs/detect/train/events.out.tfevents.1698596185.313d13fda6fe.12744.0
#   inflating: /content/content/runs/detect/train/train_batch2.jpg
#   inflating: /content/content/runs/detect/train/F1_curve.png
#   inflating: /content/content/runs/detect/train/confusion_matrix.png
#   inflating: /content/content/runs/detect/train/P_curve.png
# ...

# %%
# !yolo detect val model=/content/drive/MyDrive/skenny/default.pt data=/content/datasets/dataset.yaml plots=True save_json=True
# Out:
# 2024-01-21 13:36:22.140457: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-21 13:36:22.140512: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-21 13:36:22.141818: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-21 13:36:23.518853: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
# !cp -r /content/runs /content/drive/MyDrive/skenny/detect
